# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %%
#使用numpy生成200个随机点
x_data = np.linspace(-0.5,0.5,200)[:,np.newaxis]
noise = np.random.normal(0,0.02,x_data.shape)
y_data = np.square(x_data) + noise

#定义两个placehoder
x = tf.placeholder(tf.float32,[None,1])
y = tf.placeholder(tf.float32,[None,1])

#定义神经网络中间层
Weight_L1 = tf.Variable(tf.random_normal([1,10]))
biases_L1 = tf.Variable(tf.zeros([1,10]))
Wx_plus_b_L1 = tf.matmul(x,Weight_L1) + biases_L1
L1 = tf.nn.tanh(Wx_plus_b_L1)

#定义神经网络输出层
Weight_L2 = tf.Variable(tf.random_normal([10,1]))
biases_L2 = tf.Variable(tf.zeros([1,1]))
Wx_plus_b_L2 = tf.matmul(L1,Weight_L2) + biases_L2
prediction = tf.nn.tanh(Wx_plus_b_L2)

#二次代价函数
loss = tf.reduce_mean(tf.square(y-prediction))
#使用梯度下降法训练
train_step = tf.train.GradientDescentOptimizer(0,1).minimize(loss)

with tf.Session() as sess:
    #变量的初始化
    sess.run(tf.global_variables_initializer())
    for _ in range(2000):
        sess.run(train_step,feed_dict={x:x_data,y:y_data})
        
    #获得预测值
    prediction_value = sess.run(prediction,feed_dict={x:x_data})
    #画图
    plt.figure()
    plt.scatter(x_data,y_data)
    plt.plot(x_data,prediction_value,'r-',lw=5)
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-2467e8469bb1> in <module>()
#      23 loss = tf.reduce_mean(tf.square(y-prediction))
#      24 #使用梯度下降法训练
# ---> 25 train_step = tf.train.GradientDescentOptimizer(0,1).minimize(loss)
#      26
#      27 with tf.Session() as sess:
#
# C:\Users\风见\Anaconda3\lib\site-packages\tensorflow\python\training\optimizer.py in minimize(self, loss, global_step, var_list, gate_gradients, aggregation_method, colocate_gradients_with_ops, name, grad_loss)
#     408
#     409     return self.apply_gradients(grads_and_vars, global_step=global_step,
# --> 410                                 name=name)
#     411
#     412   def compute_gradients(self, loss, var_list=None,
#
# C:\Users\风见\Anaconda3\lib\site-packages\tensorflow\python\training\optimizer.py in apply_gradients(self, grads_and_vars, global_step, name)
#     603           scope_name = var.op.name
#     604         with ops.name_scope("update_" + scope_name), ops.colocate_with(var):
# --> 605           update_ops.append(processor.update_op(self, grad))
#     606       if global_step is None:
#     607         apply_updates = self._finish(update_ops, name)
#
# C:\Users\风见\Anaconda3\lib\site-packages\tensorflow\python\training\optimizer.py in update_op(self, optimizer, g)
#     112   def update_op(self, optimizer, g):
#     113     if isinstance(g, ops.Tensor):
# --> 114       update_op = optimizer._apply_dense(g, self._v)  # pylint: disable=protected-access
#     115       if self._v.constraint is not None:
#     116         with ops.control_dependencies([update_op]):
#
# C:\Users\风见\Anaconda3\lib\site-packages\tensorflow\python\training\gradient_descent.py in _apply_dense(self, grad, var)
#      58         math_ops.cast(self._learning_rate_tensor, var.dtype.base_dtype),
#      59         grad,
# ---> 60         use_locking=self._use_locking).op
#      61
#      62   def _resource_apply_dense(self, grad, handle):
#
# C:\Users\风见\Anaconda3\lib\site-packages\tensorflow\python\training\gen_training_ops.py in apply_gradient_descent(var, alpha, delta, use_locking, name)
#     625     if use_locking is None:
#     626       use_locking = False
# --> 627     use_locking = _execute.make_bool(use_locking, "use_locking")
#     628     _, _, _op = _op_def_lib._apply_op_helper(
#     629         "ApplyGradientDescent", var=var, alpha=alpha, delta=delta,
#
# C:\Users\风见\Anaconda3\lib\site-packages\tensorflow\python\eager\execute.py in make_bool(v, arg_name)
#     115   if not isinstance(v, bool):
#     116     raise TypeError("Expected bool for argument '%s' not %s." %
# --> 117                     (arg_name, repr(v)))
#     118   return v
#     119
#
# TypeError: Expected bool for argument 'use_locking' not 1.

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt


#使用numpy生成200个随机点
x_data = np.linspace(-0.5,0.5,200)[:,np.newaxis]
noise = np.random.normal(0,0.02,x_data.shape)
y_data = np.square(x_data) + noise

#定义两个placeholder
x = tf.placeholder(tf.float32,[None,1])
y = tf.placeholder(tf.float32,[None,1])

#定义神经网络中间层
Weights_L1 = tf.Variable(tf.random_normal([1,10]))
biases_L1 = tf.Variable(tf.zeros([1,10]))
Wx_plus_b_L1 = tf.matmul(x,Weights_L1) + biases_L1
L1 = tf.nn.tanh(Wx_plus_b_L1)

#定义神经网络输出层
Weights_L2 = tf.Variable(tf.random_normal([10,1]))
biases_L2 = tf.Variable(tf.zeros([1,1]))
Wx_plus_b_L2 = tf.matmul(L1,Weights_L2) + biases_L2
prediction = tf.nn.tanh(Wx_plus_b_L2)

#二次代价函数
loss = tf.reduce_mean(tf.square(y-prediction))
#使用梯度下降法训练
train_step = tf.train.GradientDescentOptimizer(0.1).minimize(loss)

with tf.Session() as sess:
    #变量初始化
    sess.run(tf.global_variables_initializer())
    for _ in range(2000):
        sess.run(train_step,feed_dict={x:x_data,y:y_data})
        
    #获得预测值
    prediction_value = sess.run(prediction,feed_dict={x:x_data})
    #画图
    plt.figure()
    plt.scatter(x_data,y_data)
    plt.plot(x_data,prediction_value,'r-',lw=5)
    plt.show()
